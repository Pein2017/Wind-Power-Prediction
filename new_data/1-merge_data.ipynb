# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm

train_input_path = 'train_input_merge.csv'
train_power_farm_path = 'train_power_farm.csv'

test_input_path = 'test_power_farm.csv'
test_power_farm_path = 'test_power_farm.csv'

train_input = pd.read_csv(train_input_path)
train_power_farm = pd.read_csv(train_power_farm_path)

test_input = pd.read_csv(test_input_path)
test_power_farm = pd.read_csv(test_power_farm_path)

# %%
train_input.columns
# Out:
# Index(['initial_time', 'time', 'lead_hour', 'altitude', 'azimuth', 'u100',
#        'v100', 'fg10', 'u10', 'v10',
#        ...
#        'uvb', 'v10n', 'vimd', 'p3020', 'viwve', 'viwvn', 'zust', 'ws200',
#        'ws100', 'ws10'],
#       dtype='object', length=131)

# %%
from sklearn.preprocessing import StandardScaler
# Ignore the first 3 columns
X = train_input.iloc[:, 3:]

# Scale the features using StandardScaler
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# Iterative VIF selection
vif_threshold = 50
max_vif = float('inf')
iteration = 1

while max_vif > vif_threshold:
    print(f"Iteration {iteration}:")
    X_with_constant = sm.add_constant(X)
    vif_data = pd.DataFrame()
    vif_data["Feature"] = X.columns
    vif_data["VIF"] = [variance_inflation_factor(X_with_constant.values, i + 1) for i in range(len(X.columns))]
    
    max_vif = vif_data["VIF"].max()
    print(vif_data)

    if max_vif > vif_threshold:
        feature_to_remove = vif_data.loc[vif_data["VIF"].idxmax(), "Feature"]
        print(f"Removing feature with highest VIF: {feature_to_remove} (VIF={max_vif})")
        X = X.drop(columns=[feature_to_remove])
    else:
        print(f"All features have VIF below the threshold of {vif_threshold}.")

    iteration += 1

# Final selected features
print("Final selected features:")
print(X.columns.tolist())
# Out:
# Iteration 1:
#       Feature          VIF
# 0    altitude    10.168717
# 1     azimuth     2.101530
# 2        u100  1544.342219
# 3        v100  2970.205947
# 4        fg10    84.307642
# ..        ...          ...
# 123     viwvn    11.392286
# 124      zust   843.203633
# 125     ws200   317.243789
# 126     ws100  1108.036903
# 127      ws10   816.853848
#
# [128 rows x 2 columns]
# Removing feature with highest VIF: lblt (VIF=677071394.9670656)
# Iteration 2:
#       Feature          VIF
# 0    altitude    10.151434
# 1     azimuth     2.101048
# 2        u100  1543.813641
# 3        v100  2970.061382
# 4        fg10    84.096957
# ..        ...          ...
# 122     viwvn    11.392268
# 123      zust   843.093398
# 124     ws200   317.218837
# 125     ws100  1107.694582
# 126      ws10   816.604539
#
# [127 rows x 2 columns]
# Removing feature with highest VIF: lmlt (VIF=290696749.7014346)
# Iteration 3:
#       Feature          VIF
# 0    altitude    10.150900
# 1     azimuth     2.100685
# 2        u100  1543.774904
# 3        v100  2968.718596
# 4        fg10    84.085547
# ..        ...          ...
# 121     viwvn    11.392262
# 122      zust   842.826552
# 123     ws200   317.162132
# 124     ws100  1107.635361
# 125      ws10   816.177328
#
# [126 rows x 2 columns]
# Removing feature with highest VIF: tcw (VIF=9968483.946505183)
# Iteration 4:
#       Feature          VIF
# 0    altitude    10.150895
# 1     azimuth     2.100675
# 2        u100  1543.637734
# 3        v100  2966.604033
# 4        fg10    84.061869
# ..        ...          ...
# 120     viwvn    11.391485
# 121      zust   842.756278
# 122     ws200   317.048159
# 123     ws100  1107.180871
# 124      ws10   816.174931
#
# [125 rows x 2 columns]
# Removing feature with highest VIF: ltlt (VIF=3650944.9559473447)
# Iteration 5:
#       Feature          VIF
# 0    altitude    10.148809
# 1     azimuth     2.098632
# 2        u100  1541.493384
# 3        v100  2964.486316
# 4        fg10    83.919731
# ..        ...          ...
# 119     viwvn    11.391229
# 120      zust   842.755830
# 121     ws200   316.664710
# 122     ws100  1105.961804
# 123      ws10   816.079772
#
# [124 rows x 2 columns]
# Removing feature with highest VIF: ssr (VIF=778578.9119797929)
# Iteration 6:
#       Feature          VIF
# 0    altitude     9.561841
# 1     azimuth     2.097370
# 2        u100  1541.447225
# 3        v100  2961.831335
# 4        fg10    83.886083
# ..        ...          ...
# 118     viwvn    11.384748
# 119      zust   842.707417
# 120     ws200   316.643928
# 121     ws100  1105.961535
# 122      ws10   816.079685
#
# [123 rows x 2 columns]
# Removing feature with highest VIF: stl3 (VIF=670137.4282265457)
# Iteration 7:
#       Feature          VIF
# 0    altitude     9.554070
# 1     azimuth     2.097235
# 2        u100  1540.442642
# 3        v100  2959.219468
# 4        fg10    83.785898
# ..        ...          ...
# 117     viwvn    11.384726
# 118      zust   842.624122
# 119     ws200   316.261578
# 120     ws100  1105.539865
# 121      ws10   815.838524
#
# [122 rows x 2 columns]
# Removing feature with highest VIF: stl4 (VIF=607067.9305794298)
# Iteration 8:
#       Feature          VIF
# 0    altitude     9.552023
# 1     azimuth     2.096668
# 2        u100  1537.202652
# 3        v100  2958.331526
# 4        fg10    83.772984
# ..        ...          ...
# 116     viwvn    11.380942
# 117      zust   842.213829
# 118     ws200   315.752544
# 119     ws100  1103.447539
# 120      ws10   815.771352
#
# [121 rows x 2 columns]
# Removing feature with highest VIF: ssrdc (VIF=404536.6040067024)
# Iteration 9:
#       Feature          VIF
# 0    altitude     9.330939
# 1     azimuth     2.096589
# 2        u100  1536.937344
# 3        v100  2958.278055
# 4        fg10    83.718014
# ..        ...          ...
# 115     viwvn    11.379119
# 116      zust   842.074281
# 117     ws200   315.593505
# 118     ws100  1103.234516
# 119      ws10   815.746020
#
# [120 rows x 2 columns]
# Removing feature with highest VIF: stl2 (VIF=384986.9526617567)
# Iteration 10:
#       Feature          VIF
# 0    altitude     9.330832
# 1     azimuth     2.096177
# 2        u100  1535.270738
# 3        v100  2955.748234
# 4        fg10    83.506500
# ..        ...          ...
# 114     viwvn    11.377681
# 115      zust   842.074099
# 116     ws200   315.475822
# 117     ws100  1103.052291
# 118      ws10   815.744491
#
# [119 rows x 2 columns]
# Removing feature with highest VIF: msl (VIF=122200.75518602278)
# Iteration 11:
#       Feature          VIF
# 0    altitude     9.330140
# 1     azimuth     2.095467
# 2        u100  1534.282491
# 3        v100  2955.546763
# 4        fg10    83.495801
# ..        ...          ...
# 113     viwvn    11.351652
# 114      zust   841.321988
# 115     ws200   315.468664
# 116     ws100  1103.032199
# 117      ws10   815.653652
#
# [118 rows x 2 columns]
# Removing feature with highest VIF: tp (VIF=108522.07361397009)
# Iteration 12:
#       Feature          VIF
# 0    altitude     9.327709
# 1     azimuth     2.095464
# 2        u100  1534.008523
# 3        v100  2955.505951
# 4        fg10    83.487038
# ..        ...          ...
# 112     viwvn    11.351638
# 113      zust   841.219741
# 114     ws200   315.392656
# 115     ws100  1102.621190
# 116      ws10   815.538345
#
# [117 rows x 2 columns]
# Removing feature with highest VIF: skt (VIF=50632.10985605777)
# Iteration 13:
#       Feature          VIF
# 0    altitude     9.230069
# 1     azimuth     2.094394
# 2        u100  1534.006606
# 3        v100  2954.911528
# 4        fg10    83.387371
# ..        ...          ...
# 111     viwvn    11.332796
# 112      zust   841.154728
# 113     ws200   315.388042
# 114     ws100  1101.577124
# 115      ws10   812.101382
#
# [116 rows x 2 columns]
# Removing feature with highest VIF: strd (VIF=22976.895014865608)
# Iteration 14:
#       Feature          VIF
# 0    altitude     9.224207
# 1     azimuth     2.088932
# 2        u100  1529.807158
# 3        v100  2948.626035
# 4        fg10    83.258517
# ..        ...          ...
# 110     viwvn    11.325479
# 111      zust   839.046565
# 112     ws200   314.383458
# 113     ws100  1100.557693
# 114      ws10   812.000921
#
# [115 rows x 2 columns]
# Removing feature with highest VIF: tsrc (VIF=18812.826940392762)
# Iteration 15:
#       Feature          VIF
# 0    altitude     8.954055
# 1     azimuth     2.087537
# 2        u100  1524.198661
# 3        v100  2948.543258
# 4        fg10    83.148729
# ..        ...          ...
# 109     viwvn    11.284659
# 110      zust   838.833941
# 111     ws200   312.081407
# 112     ws100  1095.009605
# 113      ws10   810.873833
#
# [114 rows x 2 columns]
# Removing feature with highest VIF: strdc (VIF=15396.127899982848)
# Iteration 16:
#       Feature          VIF
# 0    altitude     8.923351
# 1     azimuth     2.085462
# 2        u100  1520.408992
# 3        v100  2944.237286
# 4        fg10    82.993961
# ..        ...          ...
# 108     viwvn    11.274031
# 109      zust   832.892163
# 110     ws200   312.076795
# 111     ws100  1094.981407
# 112      ws10   810.664624
#
# [113 rows x 2 columns]
# Removing feature with highest VIF: ssrc (VIF=9225.950887136176)
# Iteration 17:
#       Feature          VIF
# 0    altitude     8.883307
# 1     azimuth     2.084524
# 2        u100  1519.425488
# 3        v100  2932.271467
# 4        fg10    82.727226
# ..        ...          ...
# 107     viwvn    11.197369
# 108      zust   830.366372
# 109     ws200   310.316070
# 110     ws100  1094.276883
# 111      ws10   810.439394
#
# [112 rows x 2 columns]
# Removing feature with highest VIF: v10 (VIF=8410.127288347096)
# Iteration 18:
#       Feature          VIF
# 0    altitude     8.871373
# 1     azimuth     2.084483
# 2        u100  1321.069852
# 3        v100  1860.585777
# 4        fg10    82.582178
# ..        ...          ...
# 106     viwvn    10.971513
# 107      zust   792.505046
# 108     ws200   294.629504
# 109     ws100   983.131622
# 110      ws10   765.780237
#
# [111 rows x 2 columns]
# Removing feature with highest VIF: stl1 (VIF=7772.81976792704)
# Iteration 19:
#       Feature          VIF
# 0    altitude     8.845019
# 1     azimuth     2.080768
# 2        u100  1319.131551
# 3        v100  1854.285282
# 4        fg10    82.240550
# ..        ...          ...
# 105     viwvn    10.962610
# 106      zust   786.191010
# 107     ws200   290.029223
# 108     ws100   980.915089
# 109      ws10   765.688161
#
# [110 rows x 2 columns]
# Removing feature with highest VIF: parcs (VIF=5001.022948699563)
# Iteration 20:
#       Feature          VIF
# 0    altitude     8.629239
# 1     azimuth     2.080758
# 2        u100  1317.107303
# 3        v100  1850.119472
# 4        fg10    82.240367
# ..        ...          ...
# 104     viwvn    10.952520
# 105      zust   783.706323
# 106     ws200   289.904456
# 107     ws100   978.273751
# 108      ws10   764.853795
#
# [109 rows x 2 columns]
# Removing feature with highest VIF: u10 (VIF=3763.08220483068)
# Iteration 21:
#       Feature          VIF
# 0    altitude     8.622685
# 1     azimuth     2.080479
# 2        u100   735.446904
# 3        v100  1685.944324
# 4        fg10    82.230573
# ..        ...          ...
# 103     viwvn    10.887865
# 104      zust   782.269838
# 105     ws200   250.197914
# 106     ws100   703.550517
# 107      ws10   665.590343
#
# [108 rows x 2 columns]
# Removing feature with highest VIF: e (VIF=3092.041794005303)
# Iteration 22:
#       Feature          VIF
# 0    altitude     8.621993
# 1     azimuth     2.080459
# 2        u100   735.352655
# 3        v100  1685.941804
# 4        fg10    82.230561
# ..        ...          ...
# 102     viwvn    10.887755
# 103      zust   782.240259
# 104     ws200   250.151274
# 105     ws100   703.531503
# 106      ws10   665.582715
#
# [107 rows x 2 columns]
# Removing feature with highest VIF: t2m (VIF=3037.3448901542815)
# Iteration 23:
#       Feature          VIF
# 0    altitude     8.540695
# 1     azimuth     2.079767
# 2        u100   733.866854
# 3        v100  1685.901734
# 4        fg10    81.012484
# ..        ...          ...
# 101     viwvn    10.874229
# 102      zust   782.140726
# 103     ws200   248.905026
# 104     ws100   703.361812
# 105      ws10   663.028315
#
# [106 rows x 2 columns]
# Removing feature with highest VIF: ssrd (VIF=1805.970390444209)
# Iteration 24:
#       Feature          VIF
# 0    altitude     8.537079
# 1     azimuth     2.078992
# 2        u100   733.618609
# 3        v100  1685.901642
# 4        fg10    80.792646
# ..        ...          ...
# 100     viwvn    10.874132
# 101      zust   781.139057
# 102     ws200   248.586794
# 103     ws100   702.645412
# 104      ws10   662.902580
#
# [105 rows x 2 columns]
# Removing feature with highest VIF: v100 (VIF=1685.9016423362145)
# Iteration 25:
#       Feature         VIF
# 0    altitude    8.536961
# 1     azimuth    2.077176
# 2        u100  732.970608
# 3        fg10   80.633313
# 4        u200  326.111663
# ..        ...         ...
# 99      viwvn   10.827353
# 100      zust  766.923049
# 101     ws200  236.041990
# 102     ws100  700.755952
# 103      ws10  662.548881
#
# [104 rows x 2 columns]
# Removing feature with highest VIF: mn2t (VIF=1641.3409230685738)
# Iteration 26:
#       Feature         VIF
# 0    altitude    8.536917
# 1     azimuth    2.071957
# 2        u100  731.624919
# 3        fg10   78.173658
# 4        u200  325.728805
# ..        ...         ...
# 98      viwvn   10.681228
# 99       zust  765.618822
# 100     ws200  235.167384
# 101     ws100  700.737964
# 102      ws10  659.329034
#
# [103 rows x 2 columns]
# Removing feature with highest VIF: i10fg (VIF=1004.1329249444191)
# Iteration 27:
#       Feature         VIF
# 0    altitude    8.520251
# 1     azimuth    2.071941
# 2        u100  731.445234
# 3        fg10   70.557471
# 4        u200  322.277385
# ..        ...         ...
# 97      viwvn   10.681075
# 98       zust  400.723227
# 99      ws200  233.505742
# 100     ws100  700.002632
# 101      ws10  558.840804
#
# [102 rows x 2 columns]
# Removing feature with highest VIF: ie (VIF=769.8404876990043)
# Iteration 28:
#       Feature         VIF
# 0    altitude    8.518808
# 1     azimuth    2.070953
# 2        u100  728.242920
# 3        fg10   70.495440
# 4        u200  321.860215
# ..        ...         ...
# 96      viwvn   10.669271
# 97       zust  400.455134
# 98      ws200  233.445959
# 99      ws100  697.589100
# 100      ws10  554.801792
#
# [101 rows x 2 columns]
# Removing feature with highest VIF: tsr (VIF=757.4327671562525)
# Iteration 29:
#      Feature         VIF
# 0   altitude    8.501740
# 1    azimuth    2.070590
# 2       u100  727.033231
# 3       fg10   70.324255
# 4       u200  321.423763
# ..       ...         ...
# 95     viwvn   10.661781
# 96      zust  400.446204
# 97     ws200  233.280316
# 98     ws100  697.181747
# 99      ws10  554.798283
#
# [100 rows x 2 columns]
# Removing feature with highest VIF: u100 (VIF=727.0332309182166)
# Iteration 30:
#      Feature         VIF
# 0   altitude    8.493340
# 1    azimuth    2.058479
# 2       fg10   70.319819
# 3       u200   81.721333
# 4       v200  166.255192
# ..       ...         ...
# 94     viwvn   10.661381
# 95      zust  400.323509
# 96     ws200  120.876855
# 97     ws100  321.837541
# 98      ws10  434.188951
#
# [99 rows x 2 columns]
# Removing feature with highest VIF: ws10 (VIF=434.1889507607732)
# Iteration 31:
#      Feature         VIF
# 0   altitude    8.492563
# 1    azimuth    2.058167
# 2       fg10   70.275912
# 3       u200   72.738651
# 4       v200  163.152531
# ..       ...         ...
# 93     viwve    8.306924
# 94     viwvn   10.658641
# 95      zust  237.256515
# 96     ws200  118.646957
# 97     ws100  219.316345
#
# [98 rows x 2 columns]
# Removing feature with highest VIF: mx2t (VIF=343.2172142243168)
# Iteration 32:
#      Feature         VIF
# 0   altitude    8.475056
# 1    azimuth    2.056698
# 2       fg10   70.211344
# 3       u200   72.670449
# 4       v200  163.054927
# ..       ...         ...
# 92     viwve    8.306394
# 93     viwvn   10.625611
# 94      zust  226.651125
# 95     ws200  118.187549
# 96     ws100  212.661783
#
# [97 rows x 2 columns]
# Removing feature with highest VIF: par (VIF=293.9360938204017)
# Iteration 33:
#      Feature         VIF
# 0   altitude    8.448733
# 1    azimuth    2.056642
# 2       fg10   70.086430
# 3       u200   72.644684
# 4       v200  162.952921
# ..       ...         ...
# 91     viwve    8.305557
# 92     viwvn   10.610825
# 93      zust  226.542711
# 94     ws200  118.187477
# 95     ws100  212.550791
#
# [96 rows x 2 columns]
# Removing feature with highest VIF: ishf (VIF=258.8406506991499)
# Iteration 34:
#      Feature         VIF
# 0   altitude    8.448022
# 1    azimuth    2.056235
# 2       fg10   70.085988
# 3       u200   72.642800
# 4       v200  162.254962
# ..       ...         ...
# 90     viwve    8.303347
# 91     viwvn   10.599273
# 92      zust  226.292924
# 93     ws200  118.103786
# 94     ws100  212.500525
#
# [95 rows x 2 columns]
# Removing feature with highest VIF: zust (VIF=226.2929242788567)
# Iteration 35:
#      Feature         VIF
# 0   altitude    8.447393
# 1    azimuth    2.056180
# 2       fg10   59.707373
# 3       u200   68.423886
# 4       v200  151.246302
# ..       ...         ...
# 89     p3020    6.310648
# 90     viwve    8.084028
# 91     viwvn   10.203506
# 92     ws200  117.679457
# 93     ws100  178.002412
#
# [94 rows x 2 columns]
# Removing feature with highest VIF: lsrr (VIF=189.71269721676413)
# Iteration 36:
#      Feature         VIF
# 0   altitude    8.446797
# 1    azimuth    2.055914
# 2       fg10   59.467015
# 3       u200   68.410527
# 4       v200  151.127323
# ..       ...         ...
# 88     p3020    6.171672
# 89     viwve    8.083396
# 90     viwvn   10.155876
# 91     ws200  117.678764
# 92     ws100  177.992713
#
# [93 rows x 2 columns]
# Removing feature with highest VIF: ws100 (VIF=177.9927125456675)
# Iteration 37:
#      Feature         VIF
# 0   altitude    8.437495
# 1    azimuth    2.052719
# 2       fg10   57.277066
# 3       u200   67.754894
# 4       v200  151.064774
# ..       ...         ...
# 87      vimd    3.158718
# 88     p3020    6.170025
# 89     viwve    8.081580
# 90     viwvn   10.070840
# 91     ws200   36.632540
#
# [92 rows x 2 columns]
# Removing feature with highest VIF: v200 (VIF=151.06477448559568)
# Iteration 38:
#      Feature         VIF
# 0   altitude    8.415122
# 1    azimuth    2.050216
# 2       fg10   57.210303
# 3       u200   64.049838
# 4        d2m  131.062963
# ..       ...         ...
# 86      vimd    3.156808
# 87     p3020    6.161445
# 88     viwve    8.042974
# 89     viwvn    8.241358
# 90     ws200   34.589287
#
# [91 rows x 2 columns]
# Removing feature with highest VIF: sst (VIF=136.73556959833087)
# Iteration 39:
#      Feature        VIF
# 0   altitude   8.399789
# 1    azimuth   2.039922
# 2       fg10  56.825206
# 3       u200  64.047536
# 4        d2m  42.401356
# ..       ...        ...
# 85      vimd   3.119188
# 86     p3020   5.915082
# 87     viwve   8.027203
# 88     viwvn   8.196552
# 89     ws200  32.762607
#
# [90 rows x 2 columns]
# Removing feature with highest VIF: cdir (VIF=116.24858199722165)
# Iteration 40:
#      Feature        VIF
# 0   altitude   7.835915
# 1    azimuth   2.039863
# 2       fg10  56.819918
# 3       u200  64.047447
# 4        d2m  42.400601
# ..       ...        ...
# 84      vimd   3.119163
# 85     p3020   5.849521
# 86     viwve   8.027142
# 87     viwvn   8.195931
# 88     ws200  32.721377
#
# [89 rows x 2 columns]
# Removing feature with highest VIF: mucape (VIF=98.1866137437164)
# Iteration 41:
#      Feature        VIF
# 0   altitude   7.820097
# 1    azimuth   2.026597
# 2       fg10  56.401218
# 3       u200  63.962973
# 4        d2m  42.399157
# ..       ...        ...
# 83      vimd   3.110925
# 84     p3020   5.752475
# 85     viwve   7.933690
# 86     viwvn   8.101731
# 87     ws200  31.841574
#
# [88 rows x 2 columns]
# Removing feature with highest VIF: hwbt0 (VIF=83.57774653289492)
# Iteration 42:
#      Feature        VIF
# 0   altitude   7.818599
# 1    azimuth   2.026033
# 2       fg10  56.392080
# 3       u200  63.714598
# 4        d2m  42.384951
# ..       ...        ...
# 82      vimd   3.103566
# 83     p3020   5.748843
# 84     viwve   7.932121
# 85     viwvn   8.067549
# 86     ws200  31.556023
#
# [87 rows x 2 columns]
# Removing feature with highest VIF: uvb (VIF=81.80912015517116)
# Iteration 43:
#      Feature        VIF
# 0   altitude   7.804071
# 1    azimuth   2.024268
# 2       fg10  56.383110
# 3       u200  63.714238
# 4        d2m  42.258717
# ..       ...        ...
# 81      vimd   3.102743
# 82     p3020   5.653921
# 83     viwve   7.931570
# 84     viwvn   8.067024
# 85     ws200  31.498901
#
# [86 rows x 2 columns]
# Removing feature with highest VIF: tprate (VIF=70.07988453750683)
# Iteration 44:
#      Feature        VIF
# 0   altitude   7.795691
# 1    azimuth   2.024254
# 2       fg10  56.367522
# 3       u200  63.627634
# 4        d2m  42.218371
# ..       ...        ...
# 80      vimd   3.092922
# 81     p3020   5.633073
# 82     viwve   7.931516
# 83     viwvn   8.065627
# 84     ws200  31.376215
#
# [85 rows x 2 columns]
# Removing feature with highest VIF: strc (VIF=70.06245883990643)
# Iteration 45:
#      Feature        VIF
# 0   altitude   7.791414
# 1    azimuth   2.020273
# 2       fg10  56.281387
# 3       u200  62.322558
# 4        d2m  42.167554
# ..       ...        ...
# 79      vimd   3.084446
# 80     p3020   5.165768
# 81     viwve   7.925275
# 82     viwvn   7.805758
# 83     ws200  27.529387
#
# [84 rows x 2 columns]
# Removing feature with highest VIF: u10n (VIF=66.92989544204394)
# Iteration 46:
#      Feature        VIF
# 0   altitude   7.786725
# 1    azimuth   2.020263
# 2       fg10  56.213909
# 3       u200  22.817655
# 4        d2m  42.118008
# ..       ...        ...
# 78      vimd   3.056795
# 79     p3020   5.165350
# 80     viwve   7.924092
# 81     viwvn   7.759771
# 82     ws200  24.335839
#
# [83 rows x 2 columns]
# Removing feature with highest VIF: fg10 (VIF=56.21390914240695)
# Iteration 47:
#      Feature        VIF
# 0   altitude   7.728491
# 1    azimuth   2.020239
# 2       u200  18.047335
# 3        d2m  41.897334
# 4        bld   3.248191
# ..       ...        ...
# 77      vimd   2.981069
# 78     p3020   5.155725
# 79     viwve   7.831464
# 80     viwvn   7.741026
# 81     ws200  16.611509
#
# [82 rows x 2 columns]
# All features have VIF below the threshold of 50.
# Final selected features:
# ['altitude', 'azimuth', 'u200', 'd2m', 'bld', 'blh', 'cape', 'capes', 'chnk', 'cp', 'crr', 'csfr', 'deg0l', 'degm10l', 'dsrp', 'es', 'ewss', 'fal', 'fdir', 'flsr', 'fsr', 'fzra', 'gwd', 'hcc', 'hwbt1', 'iews', 'ilspf', 'inss', 'istl1', 'istl2', 'istl3', 'istl4', 'kx', 'lcc', 'lgws', 'licd', 'lict', 'litoti', 'lspf', 'lsp', 'lssfr', 'mcc', 'mgws', 'mlcape100', 'mlcape50', 'mld', 'mudlp', 'mxtpr', 'nsss', 'uoe', 'von', 'pev', 'totalx', 'ro', 'sf', 'slhf', 'smlt', 'sp', 'sro', 'sshf', 'ssro', 'str', 'sund', 'tcc', 'tciw', 'tclw', 'tco3', 'tcrw', 'tcslw', 'tcsw', 'tcwv', 'tisr', 'trpp', 'tsn', 'ttrc', 'ttr', 'v10n', 'vimd', 'p3020', 'viwve', 'viwvn', 'ws200']

# %%
print(f"Final selected features: with shape {X.shape}")
print(X.columns.tolist())
# save the X.columns to csv
saved = pd.DataFrame(X.columns.tolist())
saved.to_csv('1-vif_82_feat.csv', index=False,columns=['feat'])
# Out:
# Final selected features: with shape (14592, 82)
# ['altitude', 'azimuth', 'u200', 'd2m', 'bld', 'blh', 'cape', 'capes', 'chnk', 'cp', 'crr', 'csfr', 'deg0l', 'degm10l', 'dsrp', 'es', 'ewss', 'fal', 'fdir', 'flsr', 'fsr', 'fzra', 'gwd', 'hcc', 'hwbt1', 'iews', 'ilspf', 'inss', 'istl1', 'istl2', 'istl3', 'istl4', 'kx', 'lcc', 'lgws', 'licd', 'lict', 'litoti', 'lspf', 'lsp', 'lssfr', 'mcc', 'mgws', 'mlcape100', 'mlcape50', 'mld', 'mudlp', 'mxtpr', 'nsss', 'uoe', 'von', 'pev', 'totalx', 'ro', 'sf', 'slhf', 'smlt', 'sp', 'sro', 'sshf', 'ssro', 'str', 'sund', 'tcc', 'tciw', 'tclw', 'tco3', 'tcrw', 'tcslw', 'tcsw', 'tcwv', 'tisr', 'trpp', 'tsn', 'ttrc', 'ttr', 'v10n', 'vimd', 'p3020', 'viwve', 'viwvn', 'ws200']

# %%
from sklearn.feature_selection import VarianceThreshold
# Assuming a variance threshold of 0.01 for demonstration purposes
variance_selector = VarianceThreshold(threshold=0.01)
X_variance_selected = variance_selector.fit_transform(X)

# Get the column names of the features that are kept after variance thresholding
selected_features_after_variance = X.columns[variance_selector.get_support()]

print("Features selected after applying VarianceThreshold:",len(selected_features_after_variance))
print(selected_features_after_variance.tolist())
# Out:
# Features selected after applying VarianceThreshold: 52
# ['altitude', 'azimuth', 'u200', 'd2m', 'bld', 'blh', 'cape', 'capes', 'deg0l', 'degm10l', 'dsrp', 'ewss', 'fdir', 'flsr', 'gwd', 'hcc', 'hwbt1', 'ilspf', 'kx', 'lcc', 'lgws', 'litoti', 'lspf', 'mcc', 'mgws', 'mlcape100', 'mlcape50', 'mld', 'mudlp', 'nsss', 'uoe', 'von', 'totalx', 'slhf', 'sp', 'sshf', 'str', 'sund', 'tcc', 'tcrw', 'tcsw', 'tcwv', 'tisr', 'trpp', 'ttrc', 'ttr', 'v10n', 'vimd', 'p3020', 'viwve', 'viwvn', 'ws200']

# %%
saved = pd.DataFrame(selected_features_after_variance.tolist(), columns=['feat'])
saved.to_csv('2-var_thres_52_feat.csv',index=False)

# %%
import pandas as pd
# File paths
train_input_path = 'train_input_merge.csv'
train_power_farm_path = 'train_power_farm.csv'

test_input_path = 'test_input_merge.csv'
test_power_farm_path = 'test_power_farm.csv'

selected_features_path = '2-var_thres_52_feat.csv'

# Load data
train_input = pd.read_csv(train_input_path)
train_power_farm = pd.read_csv(train_power_farm_path)
test_input = pd.read_csv(test_input_path)
test_power_farm = pd.read_csv(test_power_farm_path)

# Load selected features
selected_features_df = pd.read_csv(selected_features_path)
selected_features = selected_features_df['feat'].tolist()
selected_features = [col.strip().lower() for col in selected_features]

# Ensure the 'time' column is retained for later checks
selected_features.append('time')
selected_features.append('lead_hour')

# %%
print(train_input.columns)
print(test_input.columns)
# Out:
# Index(['initial_time', 'time', 'lead_hour', 'altitude', 'azimuth', 'u100',
#        'v100', 'fg10', 'u10', 'v10',
#        ...
#        'uvb', 'v10n', 'vimd', 'p3020', 'viwve', 'viwvn', 'zust', 'ws200',
#        'ws100', 'ws10'],
#       dtype='object', length=131)
# Index(['initial_time', 'time', 'lead_hour', 'altitude', 'azimuth', 'u100',
#        'v100', 'fg10', 'u10', 'v10',
#        ...
#        'uvb', 'v10n', 'vimd', 'p3020', 'viwve', 'viwvn', 'zust', 'ws200',
#        'ws100', 'ws10'],
#       dtype='object', length=131)

# %%
# Drop columns not in selected_features
train_input_filtered = train_input[selected_features]
test_input_filtered = test_input[selected_features]

# Print the shapes of the filtered datasets to confirm
print("Filtered train_input shape:", train_input_filtered.shape)
print("Filtered test_input shape:", test_input_filtered.shape)



# Merge the selected features with the target variable
train_X = train_input[selected_features]
train_y = train_power_farm['power']
# Out:
# Filtered train_input shape: (14592, 54)
# Filtered test_input shape: (2880, 54)

# %%
test_X = test_input[selected_features]
test_y = test_power_farm['power']

# Check if the 'time' columns are identical in the training datasets
train_time_identical = train_input['time'].equals(train_power_farm['time'])
print(f"Are 'time' columns identical in the training data? {train_time_identical}")


# Check if the 'time' columns are identical in the testing datasets
test_time_identical = test_input['time'].equals(test_power_farm['time'])
print(f"Are 'time' columns identical in the testing data? {test_time_identical}")
# Out:
# Are 'time' columns identical in the training data? True
# Are 'time' columns identical in the testing data? True

# %%
# Optionally, you can merge them into a single DataFrame
train_merged = pd.concat([train_X, train_y], axis=1)
test_merged = pd.concat([test_X, test_y], axis=1)

print("Merged training and testing data with selected features:")
print(train_merged.shape)
print(test_merged.shape)
# Out:
# Merged training and testing data with selected features:
# (14592, 55)
# (2880, 55)

# %%
# Save the merged dataframes if needed
train_merged.to_csv('3-train_merged_55.csv', index=False)
test_merged.to_csv('3-test_merged_55.csv', index=False)

# %% [markdown]
# ## Prepare the full data

# %%
import pandas as pd

train_input_path = 'train_input_merge.csv'
train_power_farm_path = 'train_power_farm.csv'

test_input_path = 'test_input_merge.csv'
test_power_farm_path = 'test_power_farm.csv'

train_X = pd.read_csv(train_input_path)
train_y = pd.read_csv(train_power_farm_path)

test_X = pd.read_csv(test_input_path)
test_y = pd.read_csv(test_power_farm_path)

# Concat X and y['power'] columns
train = pd.concat([train_X, train_y['power']], axis=1)
test = pd.concat([test_X, test_y['power']], axis=1)

print(f'shape of train is {train.shape}, shape of test is {test.shape}')
# Out:
# shape of train is (14592, 132), shape of test is (2880, 132)

# %%
train.to_csv('3-train_full_132.csv', index=False)
test.to_csv('3-test_full_132.csv', index=False)

# %% [markdown]
# ## Tree Selection
# Go to next jupyter
