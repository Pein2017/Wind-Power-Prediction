# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import mutual_info_regression, SelectKBest
from sklearn.model_selection import cross_val_score
from lightgbm import LGBMRegressor


data_dir = "/data/Pein/Pytorch/Wind-Power-Prediction/data/"
train_data = pd.read_csv(data_dir + "train_farm_92.csv")
test_data = pd.read_csv(data_dir + "test_farm_92.csv")

# %%
print(f'shape of train data: {train_data.shape}, shape of test data: {test_data.shape}')
# Out:
# shape of train data: (14592, 92), shape of test data: (2880, 92)

# %%
# Define features and target
features = [
    col for col in train_data.columns if col not in ["time", "lead_hour", "power"]
]
X = train_data[features]
y = train_data["power"]

# Define a range of k values to search over
k_values = range(60, len(features) + 1)
# k_values = [81]

# Initialize variables to store the best score and corresponding k
best_k = 0
best_score = -np.inf

# Use a LGBMRegressor for evaluating feature importance
model = LGBMRegressor(
    n_estimators=5,
    random_state=42,
    n_jobs=16,
)

# Iterate over k values to find the optimal number of features
for k in k_values:
    print("Evaluating k =", k)
    mi_selector = SelectKBest(mutual_info_regression, k=k)
    X_k_best = mi_selector.fit_transform(X, y)

    # Perform cross-validation and compute the average score
    scores = cross_val_score(
        model, X_k_best, y, cv=5, scoring="neg_mean_squared_error", n_jobs=20
    )
    average_score = np.mean(scores)

    # Update the best score and k if the current score is better
    if average_score > best_score:
        best_score = average_score
        best_k = k

# Select features using the best k
mi_selector = SelectKBest(mutual_info_regression, k=best_k)
mi_selector.fit(X, y)

selected_mi_features = np.array(features)[mi_selector.get_support()]
# Out:
# Evaluating k = 60
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027307 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15300
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015780 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043064 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15300
# [LightGBM] [Info] Total Bins 15300
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005248 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15300
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 60
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 60
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059058 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 60
# [LightGBM] [Info] Total Bins 15300
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 60
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 60
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Start training from score 523.095942
# Evaluating k = 61
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003258 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15555
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 61
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012611 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15555
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004438 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15555
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 61
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 61
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035371 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Total Bins 15555
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.063334 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15555
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 61
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 61
# [LightGBM] [Info] Start training from score 564.184079
# Evaluating k = 62
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005161 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15810
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 62
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023128 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15810
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 62
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035526 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033230 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15810
# [LightGBM] [Info] Total Bins 15810
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 62
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 62
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047116 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15810
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 62
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Start training from score 544.534260
# Evaluating k = 63
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034740 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16065
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039470 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16065
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023258 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16065
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035330 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055380 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16065
# [LightGBM] [Info] Total Bins 16065
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 63
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 63
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 63
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 63
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 63
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Start training from score 521.337161
# Evaluating k = 64
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014458 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 16320
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 64
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043403 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16320
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 64
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043844 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16320
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047190 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16320
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039390 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16320
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 64
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 64
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 64
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Start training from score 564.184079
# Evaluating k = 65
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022166 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16575
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.067488 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16575
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 65
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 65
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.027688 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 16575
# [LightGBM] [Info] Start training from score 521.337161[LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047485 seconds.
# You can set `force_col_wise=true` to remove the overhead.
#
# [LightGBM] [Info] Total Bins 16575
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.066641 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16575
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 65
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 65
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 65
# [LightGBM] [Info] Start training from score 564.184079[LightGBM] [Info] Start training from score 544.534260
#
# [LightGBM] [Info] Start training from score 550.377705
# Evaluating k = 66
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027619 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16830
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035214 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16830
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 66
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031513 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Total Bins 16830
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 66
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 66
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047390 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16830
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 66
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055224 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16830
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 66
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Start training from score 550.377705
# Evaluating k = 67
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012800 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17085[LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017986 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
#
# [LightGBM] [Info] Total Bins 17085
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 67
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 67
# [LightGBM] [Info] Start training from score 521.337161[LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035435 seconds.
# You can set `force_col_wise=true` to remove the overhead.
#
# [LightGBM] [Info] Total Bins 17085
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039413 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17085
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 67
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046983 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17085
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 67
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 67
# [LightGBM] [Info] Start training from score 564.184079
# Evaluating k = 68
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055312 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17340
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031226 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17340
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 68
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.065628 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 68
# [LightGBM] [Info] Total Bins 17340
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.051443 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17340
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034708 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Total Bins 17340
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 68
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 68
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 68
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Start training from score 523.095942
# Evaluating k = 69
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009920 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17595
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 69
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015949 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17595
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.051636 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17595
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 69
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035134 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17595
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 69
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047414 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17595
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 69
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 69
# [LightGBM] [Info] Start training from score 564.184079
# Evaluating k = 70
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020243 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17850
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042510 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17850
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 70
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 70
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.050827 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059563 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17850
# [LightGBM] [Info] Total Bins 17850
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 70
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 70
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.050615 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17850
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 70
# [LightGBM] [Info] Start training from score 523.095942
# Evaluating k = 71
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007206 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18105
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033714 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18105
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 71
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047415 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Total Bins 18105
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043268 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18105
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047534 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18105
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 71
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 71
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 71
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 71
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Start training from score 564.184079
# Evaluating k = 72
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004733 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18360
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005800 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 18360
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 72
# [LightGBM] [Info] Start training from score 550.377705[LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 72
#
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035301 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18360
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 72
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013457 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 18360
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.053149 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 72
# [LightGBM] [Info] Total Bins 18360[LightGBM] [Info] Start training from score 521.337161
#
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 72
# [LightGBM] [Info] Start training from score 523.095942
# Evaluating k = 73
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049967 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.021848 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18615
# [LightGBM] [Info] Total Bins 18615[LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.052987 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18615
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014701 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18615
#
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 73
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 73
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059260 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18615
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 73
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 73
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 73
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Start training from score 523.095942
# Evaluating k = 74
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.010061 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18870
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 74
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047494 seconds.
# You can set `force_col_wise=true` to remove the overhead.[LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047478 seconds.
# You can set `force_col_wise=true` to remove the overhead.
#
# [LightGBM] [Info] Total Bins 18870
# [LightGBM] [Info] Total Bins 18870
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 74
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.044131 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 18870
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 74
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.067572 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18870
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 74
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 74
# [LightGBM] [Info] Start training from score 521.337161
# Evaluating k = 75
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016085 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19125
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 75
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035380 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19125
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 75
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055474 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19125
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059338 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19125
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 75
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047426 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Start training from score 523.095942[LightGBM] [Info] Total Bins 19125
#
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 75
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 75
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Start training from score 550.377705
# Evaluating k = 76
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.018780 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19380
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.051300 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19380
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047183 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19380
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 76
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017329 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 19380
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 76
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 76
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.050185 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19380
# [LightGBM] [Info] Start training from score 544.534260[LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 76
#
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 76
# [LightGBM] [Info] Start training from score 564.184079
# Evaluating k = 77
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035210 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19635
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.051160 seconds.
# You can set `force_col_wise=true` to remove the overhead.[LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043292 seconds.
# You can set `force_col_wise=true` to remove the overhead.
#
# [LightGBM] [Info] Total Bins 19635[LightGBM] [Info] Total Bins 19635
#
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043006 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19635
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 77
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 77
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.087266 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19635
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 77
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 77
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 77
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Start training from score 564.184079
# Evaluating k = 78
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027362 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19890
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 78
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027361 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19890
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 78
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.067532 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19890
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039483 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 19890
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 78
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 78
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055097 seconds.
# You can set `force_col_wise=true` to remove the overhead.[LightGBM] [Info] Start training from score 550.377705
#
# [LightGBM] [Info] Total Bins 19890
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 78
# [LightGBM] [Info] Start training from score 564.184079
# Evaluating k = 79
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.019890 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20145[LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047531 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20145
#
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031700 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20145
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 79
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.050549 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20145
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 79
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 79
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 79
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.052607 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 20145
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 79
# [LightGBM] [Info] Start training from score 550.377705
# Evaluating k = 80
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.025525 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 20400
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006291 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20400
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 80
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 80
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.067078 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20400
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 80
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059321 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20400
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.067349 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Total Bins 20400
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 80
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 80
# [LightGBM] [Info] Start training from score 550.377705
# Evaluating k = 81
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.060021 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20655
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035903 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 81
# [LightGBM] [Info] Total Bins 20655
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 81
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.048897 seconds.
# You can set `force_col_wise=true` to remove the overhead.[LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Total Bins 20655
#
# [LightGBM] [Info] Start training from score 521.337161[LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059252 seconds.
# You can set `force_col_wise=true` to remove the overhead.
#
# [LightGBM] [Info] Total Bins 20655
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 81
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 81
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.045763 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20655
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 81
# [LightGBM] [Info] Start training from score 550.377705
# Evaluating k = 82
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014548 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20910
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 82[LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026124 seconds.
# You can set `force_col_wise=true` to remove the overhead.
#
# [LightGBM] [Info] Total Bins 20910
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 82
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.019739 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20910
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031029 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 20910
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.051449 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20910
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 82
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 82
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 82
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Start training from score 523.095942
# Evaluating k = 83
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047522 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21165
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 83
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.057986 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 21165
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.071280 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21165
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.069286 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 21165
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 83
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 83
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 83
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039168 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21165
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 83
# [LightGBM] [Info] Start training from score 564.184079
# Evaluating k = 84
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012536 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 21420
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 84
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027799 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21420
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 84
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043433 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21420
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.067148 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21420
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047298 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21420
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 84
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 84
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 84
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Start training from score 564.184079
# Evaluating k = 85
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022598 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21675
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 85
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047396 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21675
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 85
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027170 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.074696 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21675[LightGBM] [Info] Total Bins 21675
#
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 85
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 85
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.056095 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Total Bins 21675
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 85
# [LightGBM] [Info] Start training from score 564.184079
# Evaluating k = 86
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.013505 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21930
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 86
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015089 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21930
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 86
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055377 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21930
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 86
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.050045 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21930
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 86
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028395 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 21930
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 86
# [LightGBM] [Info] Start training from score 550.377705
# Evaluating k = 87
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035421 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 22185
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 87
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.038840 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 22184
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 87
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035855 seconds.
# You can set `force_col_wise=true` to remove the overhead.[LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046481 seconds.
# You can set `force_col_wise=true` to remove the overhead.
#
# [LightGBM] [Info] Total Bins 22185[LightGBM] [Info] Total Bins 22185
#
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 87
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 87
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047242 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 22185
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 87
# [LightGBM] [Info] Start training from score 544.534260
# Evaluating k = 88
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032933 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 22440
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 88
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059269 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 22440
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031381 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 22440
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 88
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Start training from score 521.337161
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 88
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058834 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 22440
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 88
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055222 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 22439
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 88
# [LightGBM] [Info] Start training from score 564.184079
# Evaluating k = 89
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014035 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 22694
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022378 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 22695
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 89
# [LightGBM] [Info] Start training from score 564.184079
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 89
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043364 seconds.
# You can set `force_col_wise=true` to remove the overhead.[LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027265 seconds.
# You can set `force_col_wise=true` to remove the overhead.
#
# [LightGBM] [Info] Total Bins 22695
# [LightGBM] [Info] Total Bins 22695
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 89
# [LightGBM] [Info] Start training from score 550.377705
# [LightGBM] [Info] Start training from score 544.534260
# [LightGBM] [Info] Number of data points in the train set: 11674, number of used features: 89
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035278 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 22695
# [LightGBM] [Info] Start training from score 523.095942
# [LightGBM] [Info] Number of data points in the train set: 11673, number of used features: 89
# [LightGBM] [Info] Start training from score 521.337161

# %%
print(selected_mi_features)
print(best_k, best_score)
# Out:
# ['u100' 'v100' 'fg10' 'u10' 'v10' 'u200' 'v200' 'd2m' 't2m' 'bld' 'cdir'
#  'degm10l' 'dsrp' 'ewss' 'fdir' 'flsr' 'gwd' 'hwbt0' 'hwbt1' 'i10fg'
#  'ishf' 'lblt' 'lmlt' 'lspf' 'ltlt' 'mld' 'mn2t' 'mx2t' 'nsss' 'parcs'
#  'par' 'skt' 'slhf' 'sshf' 'ssrc' 'ssrdc' 'ssrd' 'ssr' 'sst' 'stl1' 'stl2'
#  'stl3' 'stl4' 'strc' 'strdc' 'strd' 'str' 'sund' 'tcw' 'tcwv' 'tisr'
#  'tsrc' 'tsr' 'ttrc' 'ttr' 'u10n' 'uvb' 'v10n' 'vimd' 'viwvn' 'ws200'
#  'ws100' 'ws10']
# 63 -131951.70994668955

# %%
# Create new train and test data with selected features
train_data_selected = train_data[
    ["time", "lead_hour"] + selected_mi_features.tolist() + ["power"]
]
test_data_selected = test_data[
    ["time", "lead_hour"] + selected_mi_features.tolist() + ["power"]
]

# Ensure 'power' is non-zero, setting negative values to 0
train_data_selected["power"] = train_data_selected["power"].apply(lambda x: max(x, 0))
test_data_selected["power"] = test_data_selected["power"].apply(lambda x: max(x, 0))


print(train_data_selected.shape)
print(test_data_selected.shape)
# Out:
# (14592, 66)
# (2880, 66)
# /tmp/ipykernel_3337116/1846635039.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_selected["power"] = train_data_selected["power"].apply(lambda x: max(x, 0))
# /tmp/ipykernel_3337116/1846635039.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data_selected["power"] = test_data_selected["power"].apply(lambda x: max(x, 0))

# %%
# Save the resulting DataFrames
train_data_selected.to_csv(data_dir + "train_farm_66.csv", index=False)
test_data_selected.to_csv(data_dir + "test_farm_66.csv", index=False)

# %% [markdown]
# ### Feature Importance Selection
